# %% [markdown]
# !mkdir content/
# %cd content
# !git clone https://github.com/VikasOjha666/Data-generator-for-CRNN.git
# %cd Data-generator-for-CRNN
# !mkdir images/
# !python3 generate_data.py --n_samples 300000

# %%
import fnmatch
import cv2
import numpy as np
import string
import time
import math

from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import Sequence

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

import os
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.utils import shuffle
from collections import defaultdict

# %%
#char_list = string.ascii_letters+string.digits

punclist='.?:;"'
punclist2="-+/()[]!`,|*&^%$#@'"

#Character sets to choose from.
smallletters=string.ascii_lowercase
capitalletters=string.ascii_uppercase
digits=string.digits
char_list=smallletters+capitalletters+digits+punclist+punclist2

chars = defaultdict(int)
 
def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, char in enumerate(txt):
        try:
            dig_lst.append(char_list.index(char))
        except:
            print(char)
        
    return dig_lst

def find_dominant_color(image):
        #Resizing parameters
        width, height = 150,150
        image = image.resize((width, height),resample = 0)
        #Get colors from image object
        pixels = image.getcolors(width * height)
        #Sort them by count number(first element of tuple)
        sorted_pixels = sorted(pixels, key=lambda t: t[0])
        #Get the most frequent color
        dominant_color = sorted_pixels[-1][1]
        return dominant_color

def preprocess_img(img, imgSize):
    "put img into target img of size imgSize, transpose for TF and normalize gray-values"

    # there are damaged files in IAM dataset - just use black image instead
    if img is None:
        img = np.zeros([imgSize[1], imgSize[0]]) 
        print("Image None!")

    # create target image and copy sample image into it
    (wt, ht) = imgSize
    (h, w) = img.shape
    fx = w / wt
    fy = h / ht
    f = max(fx, fy)
    newSize = (max(min(wt, int(w / f)), 1),
               max(min(ht, int(h / f)), 1))  # scale according to f (result at least 1 and at most wt or ht)
    img = cv2.resize(img, newSize, interpolation=cv2.INTER_CUBIC) # INTER_CUBIC interpolation best approximate the pixels image
                                                               # see this https://stackoverflow.com/a/57503843/7338066
    most_freq_pixel=find_dominant_color(Image.fromarray(img))
    target = np.ones([ht, wt]) * most_freq_pixel  
    target[0:newSize[1], 0:newSize[0]] = img

    img = target

    return img

def counting_characters(labels):
    for label in labels:
        for char in label:
            chars[char] += 1
    return chars

# %%
print(char_list)
print(len(char_list))
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.?:;"-+/()[]!`,|*&^%$#@'
# 86

# %% [markdown]
# annot=open('content/Data-generator-for-CRNN/annotation.txt','r').readlines()
# imagenames=[]
# txts=[]
#
# for cnt in annot:
#
#     filename,txt=cnt.split('~')[0],cnt.split('~')[1].split('\n')[0]
#     imagenames.append(filename)
#     txts.append(txt)
#
#     #print(cnt.split('~')[0])
#     #print(cnt.split('~')[1].split('\n')[0])
#     #print()
#
# chars=counting_characters(txts)
#
# c = list(zip(imagenames, txts))
#
# random.shuffle(c)
#
# imagenames, txts = zip(*c)
#
#
# #random.shuffle(image_list)
#
# #image_list=os.listdir('content/Data-generator-for-CRNN/images/')
# #image_list=[filename.split(".")[0]for filename in image_list]
#
# #file_train=image_list[0:int(0.75*len(image_list))]
# #file_test=image_list[int(0.75*len(image_list)):]

# %%
annot=open('content/Data-generator-for-CRNN/annotation.txt','r').readlines()
imagenames=[]
txts=[]

for cnt in annot:

    filename,txt=cnt.split('~')[0],cnt.split('~')[1].split('\n')[0]
    imagenames.append(filename)
    txts.append(txt)
c = list(zip(imagenames, txts))

random.shuffle(c)

imagenames, txts = zip(*c)

class DataGenerator(Sequence):
    i=0
    def __init__(self, dataset,words,max_label_len,char_list, batch_size=128, shuffle=True):
        'Initialization'
        self.batch_size = batch_size
        self.dataset = dataset
        self.words = words
        self.shuffle = shuffle
        self.indexes = 0
        self.max_label_len=max_label_len
        self.char_list=char_list
        self.on_epoch_end()
    
    def __len__(self):
        'Denotes the number of batches per epoch' 
        return int(np.floor(len(self.dataset) / self.batch_size))-1
        #return math.ceil(len(self.dataset) / self.batch_size)
        
    def __getitem__(self, index):# chyba indexuje dla batcha ale nwm
        'Generate one batch of data'
        training_img = []
        training_txt = []
        train_input_length = []
        train_label_length = []
        orig_txt = []
        
        for ind in range(self.batch_size):
            img = cv2.imread('content/Data-generator-for-CRNN/images/'+imagenames[self.i],0)
            img=preprocess_img(img,(128,32))
            img=np.expand_dims(img,axis=-1)
            img = img/255.
            txt = txts[self.i]

            orig_txt.append(txt)   
            train_label_length.append(len(txt))
            train_input_length.append(31)
            training_img.append(img)
            training_txt.append(encode_to_labels(txt))
            self.i=self.i+1
            #print(" getitem index: ",index)
                #jeśli nie nadpisuje to trzeba będzie zerować z np.array()
        train_padded_txt = pad_sequences(training_txt, maxlen=self.max_label_len, padding='post', value = len(self.char_list))

        training_img = np.array(training_img)
        train_input_length = np.array(train_input_length)
        train_label_length = np.array(train_label_length)

           # valid_img = np.array(valid_img)
           # valid_input_length = np.array(valid_input_length)
           # valid_label_length = np.array(valid_label_length)

        #rint([training_img, train_padded_txt, train_input_length, train_label_length],np.zeros(len(training_img)))
        return [training_img, train_padded_txt, train_input_length, train_label_length],np.zeros(len(training_img))
         #x=[training_img, train_padded_txt, train_input_length, train_label_length]
         #y=np.zeros(len(training_img)),
    def on_epoch_end(self):
        print(" Wcale sie nie zacialem: ",self.i)
        self.i=0
   #    'Updates indexes after each epoch'
   #    self.indexes = np.arange(len(dataset))
    #   if self.shuffle == True:
     #      np.random.shuffle(self.indexes)
                     #max label len do dodania zapisane do pliku przy generowaniu i tu odczytane z pliku bedzi

prop=int(np.floor(len(imagenames)*0.9))
trainTuples=imagenames[:prop]
validTuples=imagenames[prop:]

trainTxts=txts[:prop]
validTxts=txts[prop:]  

#Podzielić imagenames losowo na valid i train a nie ten sam            
train_generator = DataGenerator(dataset=trainTuples,words=trainTxts,max_label_len=20,char_list=char_list)
valid_generator = DataGenerator(dataset=validTuples,words=validTxts,max_label_len=20,char_list=char_list)
# Out:
#  Wcale sie nie zacialem:  0
#  Wcale sie nie zacialem:  0

# %%
print(len(imagenames))
max_label_len=20
# Out:
# 2000000

# %%
#for x in char_list:
#    print(x,": ",chars[x])

# %%
inputs = Input(shape=(32,128,1))
 
# convolution layer with kernel size (3,3)
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
# poolig layer with kernel size (2,2)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)
 
conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)
 
conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)
 
conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
# poolig layer with kernel size (2,1)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)
 
conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
# Batch normalization layer
batch_norm_5 = BatchNormalization()(conv_5)
 
conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

 
conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)
 
squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)

# bidirectional LSTM layers with units=128
blstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(squeezed)
blstm_2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(blstm_1)
 
outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

# model to be used at test time
act_model = Model(inputs, outputs)
# Out:
# 2022-06-13 12:50:12.283958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.328173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.328423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.329155: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-13 12:50:12.330670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.330869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.331040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.707668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.707850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.708001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:50:12.708119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9577 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:0a:00.0, compute capability: 8.6

# %%
act_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 128, 1)]      0
#
#  conv2d (Conv2D)             (None, 32, 128, 64)       640
#
#  max_pooling2d (MaxPooling2D  (None, 16, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 32, 128)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 32, 256)        295168
#
#  conv2d_3 (Conv2D)           (None, 8, 32, 256)        590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 32, 256)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 32, 512)        1180160
#
#  batch_normalization (BatchN  (None, 4, 32, 512)       2048
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 32, 512)        2359808
#
#  batch_normalization_1 (Batc  (None, 4, 32, 512)       2048
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 32, 512)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 1, 31, 512)        1049088
#
#  lambda (Lambda)             (None, 31, 512)           0
#
#  bidirectional (Bidirectiona  (None, 31, 256)          656384
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 31, 256)          394240
#  nal)
#
#  dense (Dense)               (None, 31, 87)            22359
#
# =================================================================
# Total params: 6,625,879
# Trainable params: 6,623,831
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
 
 
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
 
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)
 
 
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=35) 
    
filepath='wszystkie_gen.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint,es]

# %% [markdown]
# #batch_size = 256
# epochs = 5
# history = model.fit(train_generator,
#                     epochs = epochs,validation_data = ([valid_img, valid_padded_txt,
#                     valid_input_length, valid_label_length],[np.zeros(len(valid_img))]),
#                     verbose = 1, callbacks = callbacks_list)

# %%
#batch_size = 256
epochs =400
history = model.fit(train_generator,epochs = epochs,verbose = 1, callbacks = callbacks_list)
# Out:
# Epoch 1/400
# 7030/7030 [==============================] - ETA: 0s - loss: 4.3593 - accuracy: 0.6335WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 7030/7030 [==============================] - 646s 91ms/step - loss: 4.3593 - accuracy: 0.6335
# Wcale sie nie zacialem:  899968
# Epoch 2/400
#  135/7030 [..............................] - ETA: 10:35 - loss: 0.7128 - accuracy: 0.8069
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <module>
#       1 #batch_size = 256
#       2 epochs =400
# ----> 3 history = model.fit(train_generator,epochs = epochs,verbose = 1, callbacks = callbacks_list)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:1389, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387 logs = tmp_logs  # No error, now safe to assign to logs.
#    1388 end_step = step + data_handler.step_increment
# -> 1389 callbacks.on_train_batch_end(end_step, logs)
#    1390 if self.stop_training:
#    1391   break
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:1106, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1102   self.seen += add_seen
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
# -> 1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py:563, in sync_to_numpy_or_python_type(tensors)
#     560     return t
#     561   return t.item() if np.ndim(t) == 0 else t
# --> 563 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:914, in map_structure(func, *structure, **kwargs)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py:914, in <listcomp>(.0)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py:557, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     554 def _to_single_numpy_or_python_type(t):
#     555   # Don't turn ragged or sparse tensors to NumPy.
#     556   if isinstance(t, tf.Tensor):
# --> 557     t = t.numpy()
#     558   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559   if not isinstance(t, (np.ndarray, np.generic)):
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1223, in _EagerTensorBase.numpy(self)
#    1200 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1201
#    1202 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1220     NumPy dtype.
#    1221 """
#    1222 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1189, in _EagerTensorBase._numpy(self)
#    1187 def _numpy(self):
#    1188   try:
# -> 1189     return self._numpy_internal()
#    1190   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
#batch_size = 256
epochs = 50
history = model.fit(train_generator,validation_data = valid_generator,epochs = epochs,verbose = 1, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 2022-06-13 12:50:19.568963: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8401
# 2022-06-13 12:50:20.504443: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-13 12:50:21.664437: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 14061/14061 [==============================] - ETA: 0s - loss: 2.3677 - accuracy: 0.7322 Wcale sie nie zacialem:  199936
#
# Epoch 1: val_loss improved from inf to 0.52570, saving model to wszystkie_gen.hdf5
# 14061/14061 [==============================] - 1421s 101ms/step - loss: 2.3677 - accuracy: 0.7322 - val_loss: 0.5257 - val_accuracy: 0.8484
#  Wcale sie nie zacialem:  1799936
# Epoch 2/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4429 - accuracy: 0.8713 Wcale sie nie zacialem:  199808
#
# Epoch 2: val_loss improved from 0.52570 to 0.46022, saving model to wszystkie_gen.hdf5
# 14061/14061 [==============================] - 1413s 100ms/step - loss: 0.4429 - accuracy: 0.8713 - val_loss: 0.4602 - val_accuracy: 0.8747
#  Wcale sie nie zacialem:  1799808
# Epoch 3/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3694 - accuracy: 0.8900 Wcale sie nie zacialem:  199808
#
# Epoch 3: val_loss improved from 0.46022 to 0.36864, saving model to wszystkie_gen.hdf5
# 14061/14061 [==============================] - 1411s 100ms/step - loss: 0.3694 - accuracy: 0.8900 - val_loss: 0.3686 - val_accuracy: 0.8962
#  Wcale sie nie zacialem:  1799808
# Epoch 4/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8972 Wcale sie nie zacialem:  199808
#
# Epoch 4: val_loss improved from 0.36864 to 0.29974, saving model to wszystkie_gen.hdf5
# 14061/14061 [==============================] - 1413s 101ms/step - loss: 0.3404 - accuracy: 0.8972 - val_loss: 0.2997 - val_accuracy: 0.9090
#  Wcale sie nie zacialem:  1799808
# Epoch 5/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.9002 Wcale sie nie zacialem:  199808
#
# Epoch 5: val_loss did not improve from 0.29974
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3295 - accuracy: 0.9002 - val_loss: 0.3583 - val_accuracy: 0.8931
#  Wcale sie nie zacialem:  1799808
# Epoch 6/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.9017 Wcale sie nie zacialem:  199808
#
# Epoch 6: val_loss did not improve from 0.29974
# 14061/14061 [==============================] - 1411s 100ms/step - loss: 0.3238 - accuracy: 0.9017 - val_loss: 0.3582 - val_accuracy: 0.8910
#  Wcale sie nie zacialem:  1799808
# Epoch 7/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.9035 Wcale sie nie zacialem:  199808
#
# Epoch 7: val_loss improved from 0.29974 to 0.27266, saving model to wszystkie_gen.hdf5
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.3189 - accuracy: 0.9035 - val_loss: 0.2727 - val_accuracy: 0.9189
#  Wcale sie nie zacialem:  1799808
# Epoch 8/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9020 Wcale sie nie zacialem:  199808
#
# Epoch 8: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 100ms/step - loss: 0.3218 - accuracy: 0.9020 - val_loss: 0.2913 - val_accuracy: 0.9132
#  Wcale sie nie zacialem:  1799808
# Epoch 9/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.9009 Wcale sie nie zacialem:  199808
#
# Epoch 9: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3240 - accuracy: 0.9009 - val_loss: 0.3128 - val_accuracy: 0.9033
#  Wcale sie nie zacialem:  1799808
# Epoch 10/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.9002 Wcale sie nie zacialem:  199808
#
# Epoch 10: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3268 - accuracy: 0.9002 - val_loss: 0.2763 - val_accuracy: 0.9163
#  Wcale sie nie zacialem:  1799808
# Epoch 11/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3298 - accuracy: 0.8992 Wcale sie nie zacialem:  199808
#
# Epoch 11: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3298 - accuracy: 0.8992 - val_loss: 0.3143 - val_accuracy: 0.9058
#  Wcale sie nie zacialem:  1799808
# Epoch 12/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8989 Wcale sie nie zacialem:  199808
#
# Epoch 12: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3317 - accuracy: 0.8989 - val_loss: 0.3089 - val_accuracy: 0.9085
#  Wcale sie nie zacialem:  1799808
# Epoch 13/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3387 - accuracy: 0.8969 Wcale sie nie zacialem:  199808
#
# Epoch 13: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3387 - accuracy: 0.8969 - val_loss: 0.2829 - val_accuracy: 0.9156
#  Wcale sie nie zacialem:  1799808
# Epoch 14/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3441 - accuracy: 0.8952 Wcale sie nie zacialem:  199808
#
# Epoch 14: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1415s 101ms/step - loss: 0.3441 - accuracy: 0.8952 - val_loss: 0.3081 - val_accuracy: 0.9091
#  Wcale sie nie zacialem:  1799808
# Epoch 15/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8958 Wcale sie nie zacialem:  199808
#
# Epoch 15: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1416s 101ms/step - loss: 0.3411 - accuracy: 0.8958 - val_loss: 0.3644 - val_accuracy: 0.8953
#  Wcale sie nie zacialem:  1799808
# Epoch 16/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8945 Wcale sie nie zacialem:  199808
#
# Epoch 16: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3443 - accuracy: 0.8945 - val_loss: 0.4130 - val_accuracy: 0.8864
#  Wcale sie nie zacialem:  1799808
# Epoch 17/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8920 Wcale sie nie zacialem:  199808
#
# Epoch 17: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1417s 101ms/step - loss: 0.3572 - accuracy: 0.8920 - val_loss: 0.3292 - val_accuracy: 0.9038
#  Wcale sie nie zacialem:  1799808
# Epoch 18/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8923 Wcale sie nie zacialem:  199808
#
# Epoch 18: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1415s 101ms/step - loss: 0.3551 - accuracy: 0.8923 - val_loss: 0.3027 - val_accuracy: 0.9089
#  Wcale sie nie zacialem:  1799808
# Epoch 19/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8908 Wcale sie nie zacialem:  199808
#
# Epoch 19: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 101ms/step - loss: 0.3620 - accuracy: 0.8908 - val_loss: 0.2814 - val_accuracy: 0.9176
#  Wcale sie nie zacialem:  1799808
# Epoch 20/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8895 Wcale sie nie zacialem:  199808
#
# Epoch 20: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3649 - accuracy: 0.8895 - val_loss: 0.3336 - val_accuracy: 0.8984
#  Wcale sie nie zacialem:  1799808
# Epoch 21/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8893 Wcale sie nie zacialem:  199808
#
# Epoch 21: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1411s 100ms/step - loss: 0.3666 - accuracy: 0.8893 - val_loss: 0.2938 - val_accuracy: 0.9101
#  Wcale sie nie zacialem:  1799808
# Epoch 22/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8861 Wcale sie nie zacialem:  199808
#
# Epoch 22: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1415s 101ms/step - loss: 0.3769 - accuracy: 0.8861 - val_loss: 0.4793 - val_accuracy: 0.8746
#  Wcale sie nie zacialem:  1799808
# Epoch 23/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8841 Wcale sie nie zacialem:  199808
#
# Epoch 23: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 100ms/step - loss: 0.3834 - accuracy: 0.8841 - val_loss: 0.3197 - val_accuracy: 0.9086
#  Wcale sie nie zacialem:  1799808
# Epoch 24/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8853 Wcale sie nie zacialem:  199808
#
# Epoch 24: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 100ms/step - loss: 0.3792 - accuracy: 0.8853 - val_loss: 0.3049 - val_accuracy: 0.9105
#  Wcale sie nie zacialem:  1799808
# Epoch 25/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.8871 Wcale sie nie zacialem:  199808
#
# Epoch 25: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3731 - accuracy: 0.8871 - val_loss: 0.3821 - val_accuracy: 0.8841
#  Wcale sie nie zacialem:  1799808
# Epoch 26/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.8855 Wcale sie nie zacialem:  199808
#
# Epoch 26: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1415s 101ms/step - loss: 0.3798 - accuracy: 0.8855 - val_loss: 0.3267 - val_accuracy: 0.9093
#  Wcale sie nie zacialem:  1799808
# Epoch 27/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8835 Wcale sie nie zacialem:  199808
#
# Epoch 27: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1416s 101ms/step - loss: 0.3858 - accuracy: 0.8835 - val_loss: 0.3481 - val_accuracy: 0.8939
#  Wcale sie nie zacialem:  1799808
# Epoch 28/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8819 Wcale sie nie zacialem:  199808
#
# Epoch 28: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3934 - accuracy: 0.8819 - val_loss: 0.3370 - val_accuracy: 0.9001
#  Wcale sie nie zacialem:  1799808
# Epoch 29/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8806 Wcale sie nie zacialem:  199808
#
# Epoch 29: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1416s 101ms/step - loss: 0.3965 - accuracy: 0.8806 - val_loss: 0.3176 - val_accuracy: 0.9063
#  Wcale sie nie zacialem:  1799808
# Epoch 30/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.8801 Wcale sie nie zacialem:  199808
#
# Epoch 30: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 101ms/step - loss: 0.3978 - accuracy: 0.8801 - val_loss: 0.3431 - val_accuracy: 0.9004
#  Wcale sie nie zacialem:  1799808
# Epoch 31/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3953 - accuracy: 0.8815 Wcale sie nie zacialem:  199808
#
# Epoch 31: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1416s 101ms/step - loss: 0.3953 - accuracy: 0.8815 - val_loss: 0.3464 - val_accuracy: 0.8933
#  Wcale sie nie zacialem:  1799808
# Epoch 32/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8805 Wcale sie nie zacialem:  199808
#
# Epoch 32: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.3965 - accuracy: 0.8805 - val_loss: 0.3399 - val_accuracy: 0.9013
#  Wcale sie nie zacialem:  1799808
# Epoch 33/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8788 Wcale sie nie zacialem:  199808
#
# Epoch 33: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4032 - accuracy: 0.8788 - val_loss: 0.3450 - val_accuracy: 0.8997
#  Wcale sie nie zacialem:  1799808
# Epoch 34/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8778 Wcale sie nie zacialem:  199808
#
# Epoch 34: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4055 - accuracy: 0.8778 - val_loss: 0.3171 - val_accuracy: 0.9053
#  Wcale sie nie zacialem:  1799808
# Epoch 35/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8753 Wcale sie nie zacialem:  199808
#
# Epoch 35: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4155 - accuracy: 0.8753 - val_loss: 0.3770 - val_accuracy: 0.8861
#  Wcale sie nie zacialem:  1799808
# Epoch 36/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8718 Wcale sie nie zacialem:  199808
#
# Epoch 36: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1411s 100ms/step - loss: 0.4265 - accuracy: 0.8718 - val_loss: 0.3435 - val_accuracy: 0.8972
#  Wcale sie nie zacialem:  1799808
# Epoch 37/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4257 - accuracy: 0.8729 Wcale sie nie zacialem:  199808
#
# Epoch 37: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1413s 101ms/step - loss: 0.4257 - accuracy: 0.8729 - val_loss: 0.3647 - val_accuracy: 0.8924
#  Wcale sie nie zacialem:  1799808
# Epoch 38/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8718 Wcale sie nie zacialem:  199808
#
# Epoch 38: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4284 - accuracy: 0.8718 - val_loss: 0.3475 - val_accuracy: 0.8981
#  Wcale sie nie zacialem:  1799808
# Epoch 39/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4261 - accuracy: 0.8724 Wcale sie nie zacialem:  199808
#
# Epoch 39: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4261 - accuracy: 0.8724 - val_loss: 0.3351 - val_accuracy: 0.8988
#  Wcale sie nie zacialem:  1799808
# Epoch 40/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4376 - accuracy: 0.8693 Wcale sie nie zacialem:  199808
#
# Epoch 40: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1414s 101ms/step - loss: 0.4376 - accuracy: 0.8693 - val_loss: 0.3597 - val_accuracy: 0.8916
#  Wcale sie nie zacialem:  1799808
# Epoch 41/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4290 - accuracy: 0.8714 Wcale sie nie zacialem:  199808
#
# Epoch 41: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4290 - accuracy: 0.8714 - val_loss: 0.3802 - val_accuracy: 0.8844
#  Wcale sie nie zacialem:  1799808
# Epoch 42/50
# 14061/14061 [==============================] - ETA: 0s - loss: 0.4432 - accuracy: 0.8679 Wcale sie nie zacialem:  199808
#
# Epoch 42: val_loss did not improve from 0.27266
# 14061/14061 [==============================] - 1412s 100ms/step - loss: 0.4432 - accuracy: 0.8679 - val_loss: 0.3715 - val_accuracy: 0.8911
# Epoch 42: early stopping

# %%
# load the saved best model weights
act_model.load_weights('wszystkie.hdf5')
 
# predict outputs on validation images
prediction = act_model.predict(valid_img[10:20])
 
# use CTC decoder
out = K.get_value(K.ctc_decode(prediction, input_length=np.ones(prediction.shape[0])*prediction.shape[1],
                         greedy=True)[0][0])
 
# see the results
i = 10
for x in out:
    print("original_text = ", valid_orig_txt[i])
    print("predicted text = ", end = '')
    for p in x:  
        if int(p) != -1:
            print(char_list[int(p)], end = '')       
    print('\n')
    i+=1

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.savefig('my_plot.png')
plt.show
