# %% [markdown]
# !mkdir content/
# %cd content
# !git clone https://github.com/VikasOjha666/Data-generator-for-CRNN.git
# %cd Data-generator-for-CRNN
# !mkdir images/
# !python3 generate_data.py --n_samples 300000

# %%
import fnmatch
import cv2
import numpy as np
import string
import time

from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
import os
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.utils import shuffle
from collections import defaultdict

# %%
#char_list = string.ascii_letters+string.digits

punclist='.?:;"'
punclist2="-+/()[]!`,|*&^%$#@'"

#Character sets to choose from.
smallletters=string.ascii_lowercase
capitalletters=string.ascii_uppercase
digits=string.digits
char_list=smallletters+capitalletters+digits+punclist+punclist2

chars = defaultdict(int)
 
def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, char in enumerate(txt):
        try:
            dig_lst.append(char_list.index(char))
        except:
            print(char)
        
    return dig_lst

def find_dominant_color(image):
        #Resizing parameters
        width, height = 150,150
        image = image.resize((width, height),resample = 0)
        #Get colors from image object
        pixels = image.getcolors(width * height)
        #Sort them by count number(first element of tuple)
        sorted_pixels = sorted(pixels, key=lambda t: t[0])
        #Get the most frequent color
        dominant_color = sorted_pixels[-1][1]
        return dominant_color

def preprocess_img(img, imgSize):
    "put img into target img of size imgSize, transpose for TF and normalize gray-values"

    # there are damaged files in IAM dataset - just use black image instead
    if img is None:
        img = np.zeros([imgSize[1], imgSize[0]]) 
        print("Image None!")

    # create target image and copy sample image into it
    (wt, ht) = imgSize
    (h, w) = img.shape
    fx = w / wt
    fy = h / ht
    f = max(fx, fy)
    newSize = (max(min(wt, int(w / f)), 1),
               max(min(ht, int(h / f)), 1))  # scale according to f (result at least 1 and at most wt or ht)
    img = cv2.resize(img, newSize, interpolation=cv2.INTER_CUBIC) # INTER_CUBIC interpolation best approximate the pixels image
                                                               # see this https://stackoverflow.com/a/57503843/7338066
    most_freq_pixel=find_dominant_color(Image.fromarray(img))
    target = np.ones([ht, wt]) * most_freq_pixel  
    target[0:newSize[1], 0:newSize[0]] = img

    img = target

    return img

def counting_characters(labels,chars):
    for label in labels:
        for char in label:
            chars[char] += 1
    return chars

# %%
print(char_list)
print(len(char_list))
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.?:;"-+/()[]!`,|*&^%$#@'
# 86

# %%
training_img = []
training_txt = []
train_input_length = []
train_label_length = []
orig_txt = []
 
#lists for validation dataset
valid_img = []
valid_txt = []
valid_input_length = []
valid_label_length = []
valid_orig_txt = []
 
max_label_len = 0

annot=open('content/Data-generator-for-CRNN/annotation.txt','r').readlines()
imagenames=[]
txts=[]

for cnt in annot:

    filename,txt=cnt.split('~')[0],cnt.split('~')[1].split('\n')[0]
    imagenames.append(filename)
    txts.append(txt)
    
    #print(cnt.split('~')[0])
    #print(cnt.split('~')[1].split('\n')[0])
    #print()

chars=counting_characters(txts,chars)

c = list(zip(imagenames, txts))

random.shuffle(c)

imagenames, txts = zip(*c)
    

    
for i in range(len(imagenames)):
        img = cv2.imread('content/Data-generator-for-CRNN/images/'+imagenames[i],0)   
 
        img=preprocess_img(img,(128,32))
        img=np.expand_dims(img,axis=-1)
        img = img/255.
        txt = txts[i]
        
        # compute maximum length of the text
        if len(txt) > max_label_len:
            max_label_len = len(txt)
            
           
        # split the 150000 data into validation and training dataset as 10% and 90% respectively
        if i%10 == 0:     
            valid_orig_txt.append(txt)   
            valid_label_length.append(len(txt))
            valid_input_length.append(31)
            valid_img.append(img)
            valid_txt.append(encode_to_labels(txt))
        else:
            orig_txt.append(txt)   
            train_label_length.append(len(txt))
            train_input_length.append(31)
            training_img.append(img)
            training_txt.append(encode_to_labels(txt)) 
        
        # break the loop if total data is 200000
        if i == 200000:
            flag = 1
            break
        i+=1

# %%
print(len(imagenames))
# Out:
# 200000

# %%
for x in char_list:
    print(x,": ",chars[x])
# Out:
# a :  24389
# b :  24685
# c :  24611
# d :  24664
# e :  24651
# f :  24437
# g :  24041
# h :  24377
# i :  24202
# j :  24372
# k :  24441
# l :  24451
# m :  24557
# n :  24392
# o :  24141
# p :  24066
# q :  24397
# r :  24170
# s :  24284
# t :  24500
# u :  24271
# v :  24422
# w :  24299
# x :  24350
# y :  24573
# z :  24351
# A :  24279
# B :  24065
# C :  24064
# D :  24301
# E :  24384
# F :  24333
# G :  24217
# H :  24516
# I :  24209
# J :  24567
# K :  24611
# L :  24328
# M :  24337
# N :  24459
# O :  24443
# P :  24230
# Q :  24382
# R :  24503
# S :  24287
# T :  24596
# U :  24276
# V :  24617
# W :  24118
# X :  24233
# Y :  24577
# Z :  24402
# 0 :  24542
# 1 :  24581
# 2 :  24184
# 3 :  24419
# 4 :  24388
# 5 :  24391
# 6 :  24530
# 7 :  24344
# 8 :  24738
# 9 :  24277
# . :  24384
# ? :  24209
# : :  24388
# ; :  24437
# " :  24634
# - :  24490
# + :  24443
# / :  24239
# ( :  24197
# ) :  24361
# [ :  24626
# ] :  24476
# ! :  24379
# ` :  24707
# , :  24531
# | :  24389
# * :  24233
# & :  24248
# ^ :  24436
# % :  24435
# $ :  24561
# # :  24302
# @ :  24380
# ' :  24507

# %%
#pad each output label to maximum text length
 
train_padded_txt = pad_sequences(training_txt, maxlen=max_label_len, padding='post', value = len(char_list))
valid_padded_txt = pad_sequences(valid_txt, maxlen=max_label_len, padding='post', value = len(char_list))

# %%
inputs = Input(shape=(32,128,1))
 
# convolution layer with kernel size (3,3)
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
# poolig layer with kernel size (2,2)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)
 
conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)
 
conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)
 
conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
# poolig layer with kernel size (2,1)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)
 
conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
# Batch normalization layer
batch_norm_5 = BatchNormalization()(conv_5)
 
conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

 
conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)
 
squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)

# bidirectional LSTM layers with units=128
blstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.5))(squeezed)
blstm_2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.5))(blstm_1)
 
outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

# model to be used at test time
act_model = Model(inputs, outputs)
# Out:
# 2022-05-23 20:24:26.866644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:26.898466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:26.898687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:26.899386: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-23 20:24:26.900597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:26.900738: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:26.900859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:27.257751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:27.258059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:27.258487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 20:24:27.258629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9409 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:0a:00.0, compute capability: 8.6

# %%
act_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 128, 1)]      0
#
#  conv2d (Conv2D)             (None, 32, 128, 64)       640
#
#  max_pooling2d (MaxPooling2D  (None, 16, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 32, 128)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 32, 256)        295168
#
#  conv2d_3 (Conv2D)           (None, 8, 32, 256)        590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 32, 256)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 32, 512)        1180160
#
#  batch_normalization (BatchN  (None, 4, 32, 512)       2048
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 32, 512)        2359808
#
#  batch_normalization_1 (Batc  (None, 4, 32, 512)       2048
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 32, 512)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 1, 31, 512)        1049088
#
#  lambda (Lambda)             (None, 31, 512)           0
#
#  bidirectional (Bidirectiona  (None, 31, 256)          656384
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 31, 256)          394240
#  nal)
#
#  dense (Dense)               (None, 31, 87)            22359
#
# =================================================================
# Total params: 6,625,879
# Trainable params: 6,623,831
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
 
 
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
 
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)
 
 
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50) 
 
    
filepath="all_rotated_1.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint,es]

# %%
training_img = np.array(training_img)
train_input_length = np.array(train_input_length)
train_label_length = np.array(train_label_length)

valid_img = np.array(valid_img)
valid_input_length = np.array(valid_input_length)
valid_label_length = np.array(valid_label_length)

# %%
batch_size = 256
epochs = 150
history = model.fit(x=[training_img, train_padded_txt, train_input_length, train_label_length], y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epochs, validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length], [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)
# Out:
# 2022-05-23 20:24:33.475449: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2949120000 exceeds 10% of free system memory.
# 2022-05-23 20:24:35.200899: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2949120000 exceeds 10% of free system memory.
# Epoch 1/150
# 2022-05-23 20:24:40.544854: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 2022-05-23 20:24:42.383619: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-05-23 20:24:44.073479: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 704/704 [==============================] - ETA: 0s - loss: 31.0594 - accuracy: 0.0171
# Epoch 1: val_loss improved from inf to 109.87601, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 148s 195ms/step - loss: 31.0594 - accuracy: 0.0171 - val_loss: 109.8760 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 703/704 [============================>.] - ETA: 0s - loss: 3.8852 - accuracy: 0.3152
# Epoch 2: val_loss improved from 109.87601 to 2.82419, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 133s 189ms/step - loss: 3.8851 - accuracy: 0.3152 - val_loss: 2.8242 - val_accuracy: 0.5235
# Epoch 3/150
# 703/704 [============================>.] - ETA: 0s - loss: 2.0717 - accuracy: 0.5462
# Epoch 3: val_loss did not improve from 2.82419
# 704/704 [==============================] - 134s 191ms/step - loss: 2.0719 - accuracy: 0.5462 - val_loss: 3.2586 - val_accuracy: 0.4933
# Epoch 4/150
# 703/704 [============================>.] - ETA: 0s - loss: 1.5013 - accuracy: 0.6405
# Epoch 4: val_loss improved from 2.82419 to 1.68757, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 1.5012 - accuracy: 0.6406 - val_loss: 1.6876 - val_accuracy: 0.6562
# Epoch 5/150
# 703/704 [============================>.] - ETA: 0s - loss: 1.2310 - accuracy: 0.6876
# Epoch 5: val_loss improved from 1.68757 to 1.38501, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 190ms/step - loss: 1.2310 - accuracy: 0.6876 - val_loss: 1.3850 - val_accuracy: 0.7309
# Epoch 6/150
# 703/704 [============================>.] - ETA: 0s - loss: 1.0442 - accuracy: 0.7231
# Epoch 6: val_loss improved from 1.38501 to 1.36232, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 1.0443 - accuracy: 0.7231 - val_loss: 1.3623 - val_accuracy: 0.7462
# Epoch 7/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.9198 - accuracy: 0.7481
# Epoch 7: val_loss improved from 1.36232 to 1.26756, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.9197 - accuracy: 0.7481 - val_loss: 1.2676 - val_accuracy: 0.7674
# Epoch 8/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.8391 - accuracy: 0.7649
# Epoch 8: val_loss did not improve from 1.26756
# 704/704 [==============================] - 134s 190ms/step - loss: 0.8391 - accuracy: 0.7649 - val_loss: 1.5151 - val_accuracy: 0.7304
# Epoch 9/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.7662 - accuracy: 0.7804
# Epoch 9: val_loss improved from 1.26756 to 1.09923, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.7663 - accuracy: 0.7804 - val_loss: 1.0992 - val_accuracy: 0.7934
# Epoch 10/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.6954 - accuracy: 0.7959
# Epoch 10: val_loss did not improve from 1.09923
# 704/704 [==============================] - 134s 191ms/step - loss: 0.6955 - accuracy: 0.7959 - val_loss: 1.1184 - val_accuracy: 0.7881
# Epoch 11/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.6508 - accuracy: 0.8060
# Epoch 11: val_loss did not improve from 1.09923
# 704/704 [==============================] - 134s 191ms/step - loss: 0.6509 - accuracy: 0.8060 - val_loss: 1.3174 - val_accuracy: 0.7671
# Epoch 12/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.6086 - accuracy: 0.8155
# Epoch 12: val_loss improved from 1.09923 to 1.02122, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.6087 - accuracy: 0.8155 - val_loss: 1.0212 - val_accuracy: 0.7986
# Epoch 13/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.5562 - accuracy: 0.8289
# Epoch 13: val_loss improved from 1.02122 to 0.96819, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 135s 191ms/step - loss: 0.5562 - accuracy: 0.8289 - val_loss: 0.9682 - val_accuracy: 0.8196
# Epoch 14/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.5298 - accuracy: 0.8345
# Epoch 14: val_loss improved from 0.96819 to 0.93794, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.5297 - accuracy: 0.8345 - val_loss: 0.9379 - val_accuracy: 0.8215
# Epoch 15/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4987 - accuracy: 0.8418
# Epoch 15: val_loss did not improve from 0.93794
# 704/704 [==============================] - 134s 190ms/step - loss: 0.4987 - accuracy: 0.8418 - val_loss: 1.0431 - val_accuracy: 0.8066
# Epoch 16/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4706 - accuracy: 0.8482
# Epoch 16: val_loss did not improve from 0.93794
# 704/704 [==============================] - 134s 190ms/step - loss: 0.4705 - accuracy: 0.8482 - val_loss: 0.9512 - val_accuracy: 0.8167
# Epoch 17/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4468 - accuracy: 0.8559
# Epoch 17: val_loss did not improve from 0.93794
# 704/704 [==============================] - 134s 190ms/step - loss: 0.4468 - accuracy: 0.8559 - val_loss: 1.2784 - val_accuracy: 0.7857
# Epoch 18/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4248 - accuracy: 0.8606
# Epoch 18: val_loss did not improve from 0.93794
# 704/704 [==============================] - 133s 190ms/step - loss: 0.4249 - accuracy: 0.8606 - val_loss: 1.2461 - val_accuracy: 0.7954
# Epoch 19/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4059 - accuracy: 0.8662
# Epoch 19: val_loss improved from 0.93794 to 0.93378, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.4060 - accuracy: 0.8662 - val_loss: 0.9338 - val_accuracy: 0.8271
# Epoch 20/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3900 - accuracy: 0.8705
# Epoch 20: val_loss did not improve from 0.93378
# 704/704 [==============================] - 133s 189ms/step - loss: 0.3900 - accuracy: 0.8705 - val_loss: 0.9910 - val_accuracy: 0.8304
# Epoch 21/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3715 - accuracy: 0.8768
# Epoch 21: val_loss did not improve from 0.93378
# 704/704 [==============================] - 134s 190ms/step - loss: 0.3716 - accuracy: 0.8768 - val_loss: 1.2614 - val_accuracy: 0.7982
# Epoch 22/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3662 - accuracy: 0.8784
# Epoch 22: val_loss did not improve from 0.93378
# 704/704 [==============================] - 134s 190ms/step - loss: 0.3661 - accuracy: 0.8784 - val_loss: 1.1234 - val_accuracy: 0.8173
# Epoch 23/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3393 - accuracy: 0.8865
# Epoch 23: val_loss improved from 0.93378 to 0.93004, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.3393 - accuracy: 0.8865 - val_loss: 0.9300 - val_accuracy: 0.8356
# Epoch 24/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3354 - accuracy: 0.8869
# Epoch 24: val_loss improved from 0.93004 to 0.89324, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.3354 - accuracy: 0.8869 - val_loss: 0.8932 - val_accuracy: 0.8363
# Epoch 25/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3182 - accuracy: 0.8918
# Epoch 25: val_loss did not improve from 0.89324
# 704/704 [==============================] - 134s 190ms/step - loss: 0.3183 - accuracy: 0.8918 - val_loss: 0.9489 - val_accuracy: 0.8389
# Epoch 26/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3182 - accuracy: 0.8922
# Epoch 26: val_loss did not improve from 0.89324
# 704/704 [==============================] - 134s 190ms/step - loss: 0.3182 - accuracy: 0.8922 - val_loss: 0.9557 - val_accuracy: 0.8340
# Epoch 27/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.8981
# Epoch 27: val_loss did not improve from 0.89324
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2984 - accuracy: 0.8981 - val_loss: 0.9315 - val_accuracy: 0.8448
# Epoch 28/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3040 - accuracy: 0.8973
# Epoch 28: val_loss did not improve from 0.89324
# 704/704 [==============================] - 134s 190ms/step - loss: 0.3040 - accuracy: 0.8973 - val_loss: 0.8966 - val_accuracy: 0.8558
# Epoch 29/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2767 - accuracy: 0.9041
# Epoch 29: val_loss did not improve from 0.89324
# 704/704 [==============================] - 133s 190ms/step - loss: 0.2767 - accuracy: 0.9041 - val_loss: 0.9597 - val_accuracy: 0.8393
# Epoch 30/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.9052
# Epoch 30: val_loss improved from 0.89324 to 0.88458, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 191ms/step - loss: 0.2770 - accuracy: 0.9052 - val_loss: 0.8846 - val_accuracy: 0.8577
# Epoch 31/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2724 - accuracy: 0.9057
# Epoch 31: val_loss did not improve from 0.88458
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2724 - accuracy: 0.9057 - val_loss: 0.9766 - val_accuracy: 0.8445
# Epoch 32/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2497 - accuracy: 0.9127
# Epoch 32: val_loss improved from 0.88458 to 0.87759, saving model to all_rotated_1.hdf5
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2497 - accuracy: 0.9127 - val_loss: 0.8776 - val_accuracy: 0.8526
# Epoch 33/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2593 - accuracy: 0.9098
# Epoch 33: val_loss did not improve from 0.87759
# 704/704 [==============================] - 133s 189ms/step - loss: 0.2592 - accuracy: 0.9098 - val_loss: 0.9278 - val_accuracy: 0.8631
# Epoch 34/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2529 - accuracy: 0.9121
# Epoch 34: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.2529 - accuracy: 0.9121 - val_loss: 0.9513 - val_accuracy: 0.8576
# Epoch 35/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2375 - accuracy: 0.9171
# Epoch 35: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2375 - accuracy: 0.9171 - val_loss: 0.9626 - val_accuracy: 0.8563
# Epoch 36/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2342 - accuracy: 0.9181
# Epoch 36: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2342 - accuracy: 0.9181 - val_loss: 1.0860 - val_accuracy: 0.8442
# Epoch 37/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2424 - accuracy: 0.9160
# Epoch 37: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2424 - accuracy: 0.9160 - val_loss: 0.9934 - val_accuracy: 0.8497
# Epoch 38/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2346 - accuracy: 0.9191
# Epoch 38: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2345 - accuracy: 0.9191 - val_loss: 0.9794 - val_accuracy: 0.8467
# Epoch 39/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2273 - accuracy: 0.9207
# Epoch 39: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.2273 - accuracy: 0.9207 - val_loss: 1.1138 - val_accuracy: 0.8382
# Epoch 40/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2359 - accuracy: 0.9186
# Epoch 40: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.2359 - accuracy: 0.9186 - val_loss: 0.9308 - val_accuracy: 0.8526
# Epoch 41/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2129 - accuracy: 0.9247
# Epoch 41: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.2129 - accuracy: 0.9247 - val_loss: 1.0330 - val_accuracy: 0.8554
# Epoch 42/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2091 - accuracy: 0.9270
# Epoch 42: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.2091 - accuracy: 0.9270 - val_loss: 1.1160 - val_accuracy: 0.8393
# Epoch 43/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9283
# Epoch 43: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.2047 - accuracy: 0.9283 - val_loss: 0.9950 - val_accuracy: 0.8604
# Epoch 44/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2078 - accuracy: 0.9279
# Epoch 44: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.2078 - accuracy: 0.9279 - val_loss: 0.9790 - val_accuracy: 0.8622
# Epoch 45/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9273
# Epoch 45: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.2043 - accuracy: 0.9273 - val_loss: 0.9464 - val_accuracy: 0.8659
# Epoch 46/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9286
# Epoch 46: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.2042 - accuracy: 0.9286 - val_loss: 1.1727 - val_accuracy: 0.8306
# Epoch 47/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1913 - accuracy: 0.9325
# Epoch 47: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1914 - accuracy: 0.9325 - val_loss: 1.0435 - val_accuracy: 0.8460
# Epoch 48/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.9297
# Epoch 48: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.2013 - accuracy: 0.9298 - val_loss: 1.0267 - val_accuracy: 0.8623
# Epoch 49/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9319
# Epoch 49: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1950 - accuracy: 0.9319 - val_loss: 0.9317 - val_accuracy: 0.8691
# Epoch 50/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9356
# Epoch 50: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1842 - accuracy: 0.9356 - val_loss: 0.9472 - val_accuracy: 0.8647
# Epoch 51/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1846 - accuracy: 0.9350
# Epoch 51: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1846 - accuracy: 0.9350 - val_loss: 0.9367 - val_accuracy: 0.8723
# Epoch 52/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1822 - accuracy: 0.9360
# Epoch 52: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1822 - accuracy: 0.9360 - val_loss: 0.9500 - val_accuracy: 0.8685
# Epoch 53/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9382
# Epoch 53: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1771 - accuracy: 0.9382 - val_loss: 0.9513 - val_accuracy: 0.8612
# Epoch 54/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1851 - accuracy: 0.9348
# Epoch 54: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1851 - accuracy: 0.9348 - val_loss: 1.0918 - val_accuracy: 0.8550
# Epoch 55/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9387
# Epoch 55: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1737 - accuracy: 0.9387 - val_loss: 1.0243 - val_accuracy: 0.8530
# Epoch 56/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9375
# Epoch 56: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1801 - accuracy: 0.9375 - val_loss: 1.0306 - val_accuracy: 0.8615
# Epoch 57/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1660 - accuracy: 0.9408
# Epoch 57: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1660 - accuracy: 0.9408 - val_loss: 1.1801 - val_accuracy: 0.8554
# Epoch 58/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1664 - accuracy: 0.9411
# Epoch 58: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1664 - accuracy: 0.9411 - val_loss: 1.0877 - val_accuracy: 0.8604
# Epoch 59/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1696 - accuracy: 0.9404
# Epoch 59: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1696 - accuracy: 0.9403 - val_loss: 0.9970 - val_accuracy: 0.8711
# Epoch 60/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9412
# Epoch 60: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1671 - accuracy: 0.9412 - val_loss: 1.0090 - val_accuracy: 0.8700
# Epoch 61/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9400
# Epoch 61: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1705 - accuracy: 0.9400 - val_loss: 1.1197 - val_accuracy: 0.8540
# Epoch 62/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9411
# Epoch 62: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1691 - accuracy: 0.9411 - val_loss: 1.1906 - val_accuracy: 0.8286
# Epoch 63/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9435
# Epoch 63: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1593 - accuracy: 0.9435 - val_loss: 1.0327 - val_accuracy: 0.8687
# Epoch 64/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1662 - accuracy: 0.9423
# Epoch 64: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1662 - accuracy: 0.9423 - val_loss: 0.9761 - val_accuracy: 0.8702
# Epoch 65/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1726 - accuracy: 0.9396
# Epoch 65: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1726 - accuracy: 0.9396 - val_loss: 1.0735 - val_accuracy: 0.8630
# Epoch 66/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9433
# Epoch 66: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1607 - accuracy: 0.9433 - val_loss: 1.0139 - val_accuracy: 0.8705
# Epoch 67/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9475
# Epoch 67: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1496 - accuracy: 0.9475 - val_loss: 1.0260 - val_accuracy: 0.8662
# Epoch 68/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1590 - accuracy: 0.9445
# Epoch 68: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1590 - accuracy: 0.9445 - val_loss: 1.0040 - val_accuracy: 0.8660
# Epoch 69/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9446
# Epoch 69: val_loss did not improve from 0.87759
# 704/704 [==============================] - 136s 193ms/step - loss: 0.1565 - accuracy: 0.9445 - val_loss: 1.0377 - val_accuracy: 0.8682
# Epoch 70/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1528 - accuracy: 0.9452
# Epoch 70: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1528 - accuracy: 0.9452 - val_loss: 0.9582 - val_accuracy: 0.8748
# Epoch 71/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1620 - accuracy: 0.9431
# Epoch 71: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1620 - accuracy: 0.9431 - val_loss: 1.0162 - val_accuracy: 0.8672
# Epoch 72/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9475
# Epoch 72: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1463 - accuracy: 0.9475 - val_loss: 1.0563 - val_accuracy: 0.8704
# Epoch 73/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9478
# Epoch 73: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1489 - accuracy: 0.9478 - val_loss: 1.0267 - val_accuracy: 0.8708
# Epoch 74/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9503
# Epoch 74: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 190ms/step - loss: 0.1437 - accuracy: 0.9503 - val_loss: 0.9372 - val_accuracy: 0.8734
# Epoch 75/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1715 - accuracy: 0.9408
# Epoch 75: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1715 - accuracy: 0.9408 - val_loss: 0.9816 - val_accuracy: 0.8684
# Epoch 76/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9474
# Epoch 76: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1484 - accuracy: 0.9474 - val_loss: 1.2281 - val_accuracy: 0.8539
# Epoch 77/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9487
# Epoch 77: val_loss did not improve from 0.87759
# 704/704 [==============================] - 134s 191ms/step - loss: 0.1463 - accuracy: 0.9487 - val_loss: 1.1294 - val_accuracy: 0.8613
# Epoch 78/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9501
# Epoch 78: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1425 - accuracy: 0.9501 - val_loss: 1.0881 - val_accuracy: 0.8593
# Epoch 79/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1497 - accuracy: 0.9472
# Epoch 79: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1497 - accuracy: 0.9472 - val_loss: 0.9741 - val_accuracy: 0.8709
# Epoch 80/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9469
# Epoch 80: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1518 - accuracy: 0.9470 - val_loss: 1.0212 - val_accuracy: 0.8702
# Epoch 81/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9467
# Epoch 81: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 192ms/step - loss: 0.1532 - accuracy: 0.9467 - val_loss: 0.9885 - val_accuracy: 0.8706
# Epoch 82/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1394 - accuracy: 0.9498
# Epoch 82: val_loss did not improve from 0.87759
# 704/704 [==============================] - 135s 191ms/step - loss: 0.1394 - accuracy: 0.9498 - val_loss: 1.0778 - val_accuracy: 0.8701
# Epoch 82: early stopping

# %%
# load the saved best model weights
act_model.load_weights('all_rotated_1.hdf5')
 
# predict outputs on validation images
prediction = act_model.predict(valid_img[10:20])
 
# use CTC decoder
out = K.get_value(K.ctc_decode(prediction, input_length=np.ones(prediction.shape[0])*prediction.shape[1],
                         greedy=True)[0][0])
 
# see the results
i = 10
for x in out:
    print("original_text = ", valid_orig_txt[i])
    print("predicted text = ", end = '')
    for p in x:  
        if int(p) != -1:
            print(char_list[int(p)], end = '')       
    print('\n')
    i+=1
# Out:
# original_text =  MAoWQ?/+#VX`8Lii
# predicted text = MAoWQ?/+#VX`8Lii
#
# original_text =  "]Bq%OsUJg|&;E2pNz
# predicted text = "]Bq%OsUJg|&;E2pNz
#
# original_text =  Ytk?-;:F/
# predicted text = Ytk?-;:F/
#
# original_text =  awDu'
# predicted text = awDu'
#
# original_text =  6p2]']/H+W).Y'jK-
# predicted text = 6p2]']/H+W).Y'jK-
#
# original_text =  c9toP%
# predicted text = c9toP%
#
# original_text =  GN]4$)!]D-t#
# predicted text = GN]4$)!]D-t#
#
# original_text =  "/e6A/6;N
# predicted text = "/e6A/6;N
#
# original_text =  RR
# predicted text = RR
#
# original_text =  O4EK,1w
# predicted text = O4EK,1w

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.savefig('all_rotated1.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
