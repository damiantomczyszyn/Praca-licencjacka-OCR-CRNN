# %% [markdown]
# !mkdir content/
# %cd content
# !git clone https://github.com/VikasOjha666/Data-generator-for-CRNN.git
# %cd Data-generator-for-CRNN
# !mkdir images/
# !python3 generate_data.py --n_samples 300000

# %%
import fnmatch
import cv2
import numpy as np
import string
import time

from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
import os
import tensorflow as tf
import random
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.utils import shuffle
from collections import defaultdict

# %%
#char_list = string.ascii_letters+string.digits

punclist='.?:;"'
punclist2="-+/()[]!`,|*&^%$#@'"

#Character sets to choose from.
smallletters=string.ascii_lowercase
capitalletters=string.ascii_uppercase
digits=string.digits
char_list=smallletters+capitalletters+digits+punclist+punclist2

chars = defaultdict(int)
 
def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, char in enumerate(txt):
        try:
            dig_lst.append(char_list.index(char))
        except:
            print(char)
        
    return dig_lst

def find_dominant_color(image):
        #Resizing parameters
        width, height = 150,150
        image = image.resize((width, height),resample = 0)
        #Get colors from image object
        pixels = image.getcolors(width * height)
        #Sort them by count number(first element of tuple)
        sorted_pixels = sorted(pixels, key=lambda t: t[0])
        #Get the most frequent color
        dominant_color = sorted_pixels[-1][1]
        return dominant_color

def preprocess_img(img, imgSize):
    "put img into target img of size imgSize, transpose for TF and normalize gray-values"

    # there are damaged files in IAM dataset - just use black image instead
    if img is None:
        img = np.zeros([imgSize[1], imgSize[0]]) 
        print("Image None!")

    # create target image and copy sample image into it
    (wt, ht) = imgSize
    (h, w) = img.shape
    fx = w / wt
    fy = h / ht
    f = max(fx, fy)
    newSize = (max(min(wt, int(w / f)), 1),
               max(min(ht, int(h / f)), 1))  # scale according to f (result at least 1 and at most wt or ht)
    img = cv2.resize(img, newSize, interpolation=cv2.INTER_CUBIC) # INTER_CUBIC interpolation best approximate the pixels image
                                                               # see this https://stackoverflow.com/a/57503843/7338066
    most_freq_pixel=find_dominant_color(Image.fromarray(img))
    target = np.ones([ht, wt]) * most_freq_pixel  
    target[0:newSize[1], 0:newSize[0]] = img

    img = target

    return img

def counting_characters(labels,chars):
    for label in labels:
        for char in label:
            chars[char] += 1
    return chars

# %%
print(char_list)
print(len(char_list))
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.?:;"-+/()[]!`,|*&^%$#@'
# 86

# %%
training_img = []
training_txt = []
train_input_length = []
train_label_length = []
orig_txt = []
 
#lists for validation dataset
valid_img = []
valid_txt = []
valid_input_length = []
valid_label_length = []
valid_orig_txt = []
 
max_label_len = 0

annot=open('content/Data-generator-for-CRNN/annotation.txt','r').readlines()
imagenames=[]
txts=[]

for cnt in annot:

    filename,txt=cnt.split('~')[0],cnt.split('~')[1].split('\n')[0]
    imagenames.append(filename)
    txts.append(txt)
    
    #print(cnt.split('~')[0])
    #print(cnt.split('~')[1].split('\n')[0])
    #print()

chars=counting_characters(txts,chars)

c = list(zip(imagenames, txts))

random.shuffle(c)

imagenames, txts = zip(*c)
    

    
for i in range(len(imagenames)):
        img = cv2.imread('content/Data-generator-for-CRNN/images/'+imagenames[i],0)   
 
        img=preprocess_img(img,(128,32))
        img=np.expand_dims(img,axis=-1)
        img = img/255.
        txt = txts[i]
        
        # compute maximum length of the text
        if len(txt) > max_label_len:
            max_label_len = len(txt)
            
           
        # split the 150000 data into validation and training dataset as 10% and 90% respectively
        if i%10 == 0:     
            valid_orig_txt.append(txt)   
            valid_label_length.append(len(txt))
            valid_input_length.append(31)
            valid_img.append(img)
            valid_txt.append(encode_to_labels(txt))
        else:
            orig_txt.append(txt)   
            train_label_length.append(len(txt))
            train_input_length.append(31)
            training_img.append(img)
            training_txt.append(encode_to_labels(txt)) 
        
        # break the loop if total data is 200000
        if i == 200000:
            flag = 1
            break
        i+=1

# %%
print(len(imagenames))
# Out:
# 200000

# %%
for x in char_list:
    print(x,": ",chars[x])
# Out:
# a :  24581
# b :  24315
# c :  24384
# d :  24246
# e :  24508
# f :  24522
# g :  24390
# h :  24362
# i :  24473
# j :  24518
# k :  24399
# l :  24198
# m :  24643
# n :  24367
# o :  24301
# p :  24685
# q :  24280
# r :  24416
# s :  24410
# t :  24266
# u :  24594
# v :  24544
# w :  24406
# x :  24447
# y :  24431
# z :  24357
# A :  24272
# B :  24626
# C :  24584
# D :  24674
# E :  24446
# F :  24688
# G :  24762
# H :  24657
# I :  24444
# J :  24587
# K :  24365
# L :  24289
# M :  24468
# N :  24598
# O :  24477
# P :  24066
# Q :  24573
# R :  24422
# S :  24636
# T :  24359
# U :  24074
# V :  24585
# W :  24460
# X :  24732
# Y :  24383
# Z :  24636
# 0 :  24621
# 1 :  24557
# 2 :  24082
# 3 :  24807
# 4 :  24462
# 5 :  24611
# 6 :  24670
# 7 :  24250
# 8 :  24256
# 9 :  24169
# . :  24558
# ? :  24536
# : :  24623
# ; :  24473
# " :  24368
# - :  24563
# + :  24508
# / :  24488
# ( :  24413
# ) :  24590
# [ :  24569
# ] :  24603
# ! :  24320
# ` :  24458
# , :  24411
# | :  24361
# * :  24275
# & :  24533
# ^ :  24597
# % :  24182
# $ :  24438
# # :  24325
# @ :  24534
# ' :  24693

# %%
#pad each output label to maximum text length
 
train_padded_txt = pad_sequences(training_txt, maxlen=max_label_len, padding='post', value = len(char_list))
valid_padded_txt = pad_sequences(valid_txt, maxlen=max_label_len, padding='post', value = len(char_list))

# %%
inputs = Input(shape=(32,128,1))
 
# convolution layer with kernel size (3,3)
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
# poolig layer with kernel size (2,2)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)
 
conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)
 
conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)
 
conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
# poolig layer with kernel size (2,1)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)
 
conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
# Batch normalization layer
batch_norm_5 = BatchNormalization()(conv_5)
 
conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

 
conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)
 
squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)

# bidirectional LSTM layers with units=128
blstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.5))(squeezed)
blstm_2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.5))(blstm_1)
 
outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

# model to be used at test time
act_model = Model(inputs, outputs)
# Out:
# 2022-05-23 12:52:21.826621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:21.852850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:21.853084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:21.854166: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-23 12:52:21.855444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:21.855583: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:21.855701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:22.210996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:22.211174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:22.211305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-23 12:52:22.211427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9772 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:0a:00.0, compute capability: 8.6

# %%
act_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 128, 1)]      0
#
#  conv2d (Conv2D)             (None, 32, 128, 64)       640
#
#  max_pooling2d (MaxPooling2D  (None, 16, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 32, 128)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 32, 256)        295168
#
#  conv2d_3 (Conv2D)           (None, 8, 32, 256)        590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 32, 256)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 32, 512)        1180160
#
#  batch_normalization (BatchN  (None, 4, 32, 512)       2048
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 32, 512)        2359808
#
#  batch_normalization_1 (Batc  (None, 4, 32, 512)       2048
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 32, 512)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 1, 31, 512)        1049088
#
#  lambda (Lambda)             (None, 31, 512)           0
#
#  bidirectional (Bidirectiona  (None, 31, 256)          656384
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 31, 256)          394240
#  nal)
#
#  dense (Dense)               (None, 31, 87)            22359
#
# =================================================================
# Total params: 6,625,879
# Trainable params: 6,623,831
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
 
 
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
 
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)
 
 
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50) 
 
    
filepath="all_rotated_1.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint,es]

# %%
training_img = np.array(training_img)
train_input_length = np.array(train_input_length)
train_label_length = np.array(train_label_length)

valid_img = np.array(valid_img)
valid_input_length = np.array(valid_input_length)
valid_label_length = np.array(valid_label_length)

# %%
batch_size = 256
epochs = 150
history = model.fit(x=[training_img, train_padded_txt, train_input_length, train_label_length], y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epochs, validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length], [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)
# Out:
# 2022-05-23 12:52:24.930139: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2949120000 exceeds 10% of free system memory.
# 2022-05-23 12:52:26.311957: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2949120000 exceeds 10% of free system memory.
# Epoch 1/150
# 2022-05-23 12:52:31.298415: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 2022-05-23 12:52:32.164478: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-05-23 12:52:33.586958: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 704/704 [==============================] - ETA: 0s - loss: 27.4544 - accuracy: 0.0498
# Epoch 1: val_loss improved from inf to 40.74269, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 134s 179ms/step - loss: 27.4544 - accuracy: 0.0498 - val_loss: 40.7427 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 703/704 [============================>.] - ETA: 0s - loss: 2.4577 - accuracy: 0.5106
# Epoch 2: val_loss improved from 40.74269 to 1.68951, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 174ms/step - loss: 2.4575 - accuracy: 0.5107 - val_loss: 1.6895 - val_accuracy: 0.7072
# Epoch 3/150
# 703/704 [============================>.] - ETA: 0s - loss: 1.3254 - accuracy: 0.6917
# Epoch 3: val_loss improved from 1.68951 to 1.31918, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 175ms/step - loss: 1.3254 - accuracy: 0.6917 - val_loss: 1.3192 - val_accuracy: 0.7639
# Epoch 4/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.9734 - accuracy: 0.7565
# Epoch 4: val_loss improved from 1.31918 to 1.07003, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 174ms/step - loss: 0.9734 - accuracy: 0.7565 - val_loss: 1.0700 - val_accuracy: 0.7970
# Epoch 5/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.7999 - accuracy: 0.7914
# Epoch 5: val_loss did not improve from 1.07003
# 704/704 [==============================] - 122s 174ms/step - loss: 0.8000 - accuracy: 0.7914 - val_loss: 1.2868 - val_accuracy: 0.7831
# Epoch 6/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.6871 - accuracy: 0.8136
# Epoch 6: val_loss improved from 1.07003 to 0.90593, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 122s 173ms/step - loss: 0.6872 - accuracy: 0.8136 - val_loss: 0.9059 - val_accuracy: 0.8182
# Epoch 7/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.5999 - accuracy: 0.8330
# Epoch 7: val_loss did not improve from 0.90593
# 704/704 [==============================] - 121s 172ms/step - loss: 0.5999 - accuracy: 0.8330 - val_loss: 0.9266 - val_accuracy: 0.8077
# Epoch 8/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.5316 - accuracy: 0.8487
# Epoch 8: val_loss improved from 0.90593 to 0.76445, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 122s 174ms/step - loss: 0.5316 - accuracy: 0.8487 - val_loss: 0.7645 - val_accuracy: 0.8446
# Epoch 9/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4852 - accuracy: 0.8592
# Epoch 9: val_loss did not improve from 0.76445
# 704/704 [==============================] - 122s 174ms/step - loss: 0.4853 - accuracy: 0.8592 - val_loss: 0.8084 - val_accuracy: 0.8462
# Epoch 10/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4434 - accuracy: 0.8691
# Epoch 10: val_loss did not improve from 0.76445
# 704/704 [==============================] - 123s 174ms/step - loss: 0.4435 - accuracy: 0.8691 - val_loss: 0.8820 - val_accuracy: 0.8456
# Epoch 11/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.4241 - accuracy: 0.8727
# Epoch 11: val_loss did not improve from 0.76445
# 704/704 [==============================] - 123s 175ms/step - loss: 0.4241 - accuracy: 0.8727 - val_loss: 0.9330 - val_accuracy: 0.8425
# Epoch 12/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3760 - accuracy: 0.8860
# Epoch 12: val_loss did not improve from 0.76445
# 704/704 [==============================] - 122s 174ms/step - loss: 0.3760 - accuracy: 0.8860 - val_loss: 0.8809 - val_accuracy: 0.8460
# Epoch 13/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8918
# Epoch 13: val_loss improved from 0.76445 to 0.74707, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 175ms/step - loss: 0.3482 - accuracy: 0.8918 - val_loss: 0.7471 - val_accuracy: 0.8648
# Epoch 14/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3265 - accuracy: 0.8987
# Epoch 14: val_loss improved from 0.74707 to 0.73859, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 174ms/step - loss: 0.3265 - accuracy: 0.8987 - val_loss: 0.7386 - val_accuracy: 0.8691
# Epoch 15/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.9033
# Epoch 15: val_loss did not improve from 0.73859
# 704/704 [==============================] - 122s 174ms/step - loss: 0.3096 - accuracy: 0.9033 - val_loss: 0.8430 - val_accuracy: 0.8629
# Epoch 16/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.3023 - accuracy: 0.9052
# Epoch 16: val_loss did not improve from 0.73859
# 704/704 [==============================] - 122s 174ms/step - loss: 0.3022 - accuracy: 0.9052 - val_loss: 0.8261 - val_accuracy: 0.8595
# Epoch 17/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2731 - accuracy: 0.9136
# Epoch 17: val_loss improved from 0.73859 to 0.66431, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 174ms/step - loss: 0.2731 - accuracy: 0.9136 - val_loss: 0.6643 - val_accuracy: 0.8798
# Epoch 18/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.9112
# Epoch 18: val_loss did not improve from 0.66431
# 704/704 [==============================] - 123s 174ms/step - loss: 0.2770 - accuracy: 0.9112 - val_loss: 0.7481 - val_accuracy: 0.8793
# Epoch 19/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2556 - accuracy: 0.9183
# Epoch 19: val_loss did not improve from 0.66431
# 704/704 [==============================] - 123s 174ms/step - loss: 0.2556 - accuracy: 0.9183 - val_loss: 0.7241 - val_accuracy: 0.8796
# Epoch 20/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2460 - accuracy: 0.9197
# Epoch 20: val_loss did not improve from 0.66431
# 704/704 [==============================] - 123s 174ms/step - loss: 0.2461 - accuracy: 0.9197 - val_loss: 0.7656 - val_accuracy: 0.8827
# Epoch 21/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.9217
# Epoch 21: val_loss improved from 0.66431 to 0.61019, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 175ms/step - loss: 0.2417 - accuracy: 0.9217 - val_loss: 0.6102 - val_accuracy: 0.8921
# Epoch 22/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2175 - accuracy: 0.9291
# Epoch 22: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.2177 - accuracy: 0.9291 - val_loss: 0.7259 - val_accuracy: 0.8770
# Epoch 23/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2187 - accuracy: 0.9291
# Epoch 23: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.2186 - accuracy: 0.9291 - val_loss: 0.6419 - val_accuracy: 0.8902
# Epoch 24/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2134 - accuracy: 0.9306
# Epoch 24: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 173ms/step - loss: 0.2134 - accuracy: 0.9306 - val_loss: 0.7589 - val_accuracy: 0.8730
# Epoch 25/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1995 - accuracy: 0.9341
# Epoch 25: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1995 - accuracy: 0.9341 - val_loss: 0.6199 - val_accuracy: 0.8964
# Epoch 26/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.2015 - accuracy: 0.9339
# Epoch 26: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.2015 - accuracy: 0.9339 - val_loss: 0.7386 - val_accuracy: 0.8921
# Epoch 27/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9348
# Epoch 27: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1975 - accuracy: 0.9348 - val_loss: 0.7474 - val_accuracy: 0.8842
# Epoch 28/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9386
# Epoch 28: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1847 - accuracy: 0.9385 - val_loss: 0.6296 - val_accuracy: 0.9013
# Epoch 29/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1758 - accuracy: 0.9415
# Epoch 29: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1758 - accuracy: 0.9415 - val_loss: 0.6493 - val_accuracy: 0.8971
# Epoch 30/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1813 - accuracy: 0.9398
# Epoch 30: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1813 - accuracy: 0.9398 - val_loss: 0.6830 - val_accuracy: 0.8910
# Epoch 31/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1727 - accuracy: 0.9422
# Epoch 31: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1727 - accuracy: 0.9422 - val_loss: 0.6509 - val_accuracy: 0.8956
# Epoch 32/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1749 - accuracy: 0.9411
# Epoch 32: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1749 - accuracy: 0.9411 - val_loss: 0.6929 - val_accuracy: 0.8978
# Epoch 33/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1716 - accuracy: 0.9425
# Epoch 33: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1716 - accuracy: 0.9425 - val_loss: 0.6651 - val_accuracy: 0.8985
# Epoch 34/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1559 - accuracy: 0.9483
# Epoch 34: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1559 - accuracy: 0.9483 - val_loss: 0.7377 - val_accuracy: 0.8924
# Epoch 35/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1595 - accuracy: 0.9466
# Epoch 35: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1596 - accuracy: 0.9466 - val_loss: 0.6497 - val_accuracy: 0.8998
# Epoch 36/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9493
# Epoch 36: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1501 - accuracy: 0.9493 - val_loss: 0.6332 - val_accuracy: 0.9067
# Epoch 37/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9467
# Epoch 37: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1611 - accuracy: 0.9467 - val_loss: 0.6512 - val_accuracy: 0.9026
# Epoch 38/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9502
# Epoch 38: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1485 - accuracy: 0.9502 - val_loss: 0.6943 - val_accuracy: 0.8909
# Epoch 39/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1480 - accuracy: 0.9500
# Epoch 39: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1480 - accuracy: 0.9500 - val_loss: 0.6442 - val_accuracy: 0.9018
# Epoch 40/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1438 - accuracy: 0.9516
# Epoch 40: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1438 - accuracy: 0.9516 - val_loss: 0.6404 - val_accuracy: 0.9060
# Epoch 41/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9521
# Epoch 41: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1401 - accuracy: 0.9521 - val_loss: 0.7417 - val_accuracy: 0.8985
# Epoch 42/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9529
# Epoch 42: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1417 - accuracy: 0.9529 - val_loss: 0.6779 - val_accuracy: 0.8990
# Epoch 43/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1385 - accuracy: 0.9532
# Epoch 43: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1385 - accuracy: 0.9532 - val_loss: 0.6510 - val_accuracy: 0.9093
# Epoch 44/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9531
# Epoch 44: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1416 - accuracy: 0.9531 - val_loss: 0.6404 - val_accuracy: 0.9018
# Epoch 45/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9569
# Epoch 45: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1275 - accuracy: 0.9569 - val_loss: 0.6156 - val_accuracy: 0.9121
# Epoch 46/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9557
# Epoch 46: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1305 - accuracy: 0.9557 - val_loss: 0.7820 - val_accuracy: 0.8905
# Epoch 47/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9570
# Epoch 47: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1258 - accuracy: 0.9570 - val_loss: 0.6712 - val_accuracy: 0.9024
# Epoch 48/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9548
# Epoch 48: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1333 - accuracy: 0.9548 - val_loss: 0.7170 - val_accuracy: 0.9014
# Epoch 49/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9566
# Epoch 49: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1278 - accuracy: 0.9566 - val_loss: 0.7440 - val_accuracy: 0.8974
# Epoch 50/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9578
# Epoch 50: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1263 - accuracy: 0.9578 - val_loss: 0.7983 - val_accuracy: 0.8947
# Epoch 51/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9570
# Epoch 51: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1278 - accuracy: 0.9570 - val_loss: 0.6564 - val_accuracy: 0.9081
# Epoch 52/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9576
# Epoch 52: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1261 - accuracy: 0.9576 - val_loss: 0.6365 - val_accuracy: 0.9137
# Epoch 53/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9562
# Epoch 53: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1314 - accuracy: 0.9562 - val_loss: 0.7302 - val_accuracy: 0.9038
# Epoch 54/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9596
# Epoch 54: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1187 - accuracy: 0.9596 - val_loss: 0.7330 - val_accuracy: 0.9003
# Epoch 55/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9590
# Epoch 55: val_loss did not improve from 0.61019
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1205 - accuracy: 0.9590 - val_loss: 0.7668 - val_accuracy: 0.8961
# Epoch 56/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9587
# Epoch 56: val_loss did not improve from 0.61019
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1214 - accuracy: 0.9587 - val_loss: 0.6955 - val_accuracy: 0.9051
# Epoch 57/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1250 - accuracy: 0.9579
# Epoch 57: val_loss improved from 0.61019 to 0.58989, saving model to all_bez_rotacji_1.hdf5
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1250 - accuracy: 0.9579 - val_loss: 0.5899 - val_accuracy: 0.9130
# Epoch 58/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9597
# Epoch 58: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1181 - accuracy: 0.9597 - val_loss: 0.6556 - val_accuracy: 0.9113
# Epoch 59/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9604
# Epoch 59: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1170 - accuracy: 0.9604 - val_loss: 0.7336 - val_accuracy: 0.9096
# Epoch 60/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9616
# Epoch 60: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1115 - accuracy: 0.9616 - val_loss: 0.6701 - val_accuracy: 0.9069
# Epoch 61/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9589
# Epoch 61: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1215 - accuracy: 0.9589 - val_loss: 0.6782 - val_accuracy: 0.9085
# Epoch 62/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1125 - accuracy: 0.9619
# Epoch 62: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1125 - accuracy: 0.9620 - val_loss: 0.7076 - val_accuracy: 0.9062
# Epoch 63/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9622
# Epoch 63: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1095 - accuracy: 0.9622 - val_loss: 0.6459 - val_accuracy: 0.9092
# Epoch 64/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9613
# Epoch 64: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1154 - accuracy: 0.9613 - val_loss: 0.6953 - val_accuracy: 0.9113
# Epoch 65/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9613
# Epoch 65: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1141 - accuracy: 0.9613 - val_loss: 0.7192 - val_accuracy: 0.9074
# Epoch 66/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.9601
# Epoch 66: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1176 - accuracy: 0.9601 - val_loss: 0.7727 - val_accuracy: 0.8986
# Epoch 67/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9625
# Epoch 67: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1114 - accuracy: 0.9625 - val_loss: 0.6429 - val_accuracy: 0.9118
# Epoch 68/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9637
# Epoch 68: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1072 - accuracy: 0.9637 - val_loss: 0.6851 - val_accuracy: 0.9097
# Epoch 69/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1052 - accuracy: 0.9649
# Epoch 69: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1052 - accuracy: 0.9649 - val_loss: 0.6985 - val_accuracy: 0.9123
# Epoch 70/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9609
# Epoch 70: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1152 - accuracy: 0.9609 - val_loss: 0.6701 - val_accuracy: 0.9101
# Epoch 71/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9643
# Epoch 71: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1056 - accuracy: 0.9643 - val_loss: 0.7390 - val_accuracy: 0.9016
# Epoch 72/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9616
# Epoch 72: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1145 - accuracy: 0.9616 - val_loss: 0.7173 - val_accuracy: 0.9101
# Epoch 73/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9650
# Epoch 73: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1023 - accuracy: 0.9650 - val_loss: 0.6701 - val_accuracy: 0.9110
# Epoch 74/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9641
# Epoch 74: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1036 - accuracy: 0.9641 - val_loss: 0.7204 - val_accuracy: 0.9108
# Epoch 75/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1253 - accuracy: 0.9585
# Epoch 75: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1253 - accuracy: 0.9585 - val_loss: 0.8021 - val_accuracy: 0.8995
# Epoch 76/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0982 - accuracy: 0.9663
# Epoch 76: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.0982 - accuracy: 0.9663 - val_loss: 0.6402 - val_accuracy: 0.9162
# Epoch 77/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.9661
# Epoch 77: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1003 - accuracy: 0.9661 - val_loss: 0.7118 - val_accuracy: 0.9109
# Epoch 78/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9618
# Epoch 78: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1118 - accuracy: 0.9618 - val_loss: 0.6762 - val_accuracy: 0.9134
# Epoch 79/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9637
# Epoch 79: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1083 - accuracy: 0.9637 - val_loss: 0.6481 - val_accuracy: 0.9155
# Epoch 80/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9670
# Epoch 80: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.0965 - accuracy: 0.9670 - val_loss: 0.7153 - val_accuracy: 0.9071
# Epoch 81/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0960 - accuracy: 0.9671
# Epoch 81: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.0960 - accuracy: 0.9671 - val_loss: 0.6840 - val_accuracy: 0.9155
# Epoch 82/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9644
# Epoch 82: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1052 - accuracy: 0.9644 - val_loss: 0.6375 - val_accuracy: 0.9186
# Epoch 83/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9642
# Epoch 83: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1062 - accuracy: 0.9642 - val_loss: 0.6639 - val_accuracy: 0.9155
# Epoch 84/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9635
# Epoch 84: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1077 - accuracy: 0.9635 - val_loss: 0.7371 - val_accuracy: 0.9000
# Epoch 85/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9605
# Epoch 85: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1172 - accuracy: 0.9605 - val_loss: 0.6587 - val_accuracy: 0.9104
# Epoch 86/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9643
# Epoch 86: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1024 - accuracy: 0.9643 - val_loss: 0.7630 - val_accuracy: 0.9030
# Epoch 87/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9623
# Epoch 87: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1120 - accuracy: 0.9623 - val_loss: 0.6970 - val_accuracy: 0.9080
# Epoch 88/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.9648
# Epoch 88: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1003 - accuracy: 0.9648 - val_loss: 0.6579 - val_accuracy: 0.9153
# Epoch 89/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9647
# Epoch 89: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1045 - accuracy: 0.9646 - val_loss: 0.6608 - val_accuracy: 0.9133
# Epoch 90/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9612
# Epoch 90: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.1143 - accuracy: 0.9612 - val_loss: 0.6255 - val_accuracy: 0.9133
# Epoch 91/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0963 - accuracy: 0.9661
# Epoch 91: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.0963 - accuracy: 0.9661 - val_loss: 0.6779 - val_accuracy: 0.9117
# Epoch 92/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0939 - accuracy: 0.9674
# Epoch 92: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.0939 - accuracy: 0.9674 - val_loss: 0.6539 - val_accuracy: 0.9117
# Epoch 93/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9653
# Epoch 93: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1001 - accuracy: 0.9653 - val_loss: 0.6824 - val_accuracy: 0.9110
# Epoch 94/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9649
# Epoch 94: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1016 - accuracy: 0.9650 - val_loss: 0.7409 - val_accuracy: 0.9064
# Epoch 95/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0861 - accuracy: 0.9701
# Epoch 95: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.0862 - accuracy: 0.9700 - val_loss: 0.7009 - val_accuracy: 0.9138
# Epoch 96/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9608
# Epoch 96: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1170 - accuracy: 0.9608 - val_loss: 0.6802 - val_accuracy: 0.9137
# Epoch 97/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9667
# Epoch 97: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.0966 - accuracy: 0.9667 - val_loss: 0.7078 - val_accuracy: 0.9143
# Epoch 98/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9665
# Epoch 98: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 174ms/step - loss: 0.0981 - accuracy: 0.9665 - val_loss: 0.6952 - val_accuracy: 0.9125
# Epoch 99/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0997 - accuracy: 0.9660
# Epoch 99: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.0996 - accuracy: 0.9660 - val_loss: 0.8064 - val_accuracy: 0.9022
# Epoch 100/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9620
# Epoch 100: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1120 - accuracy: 0.9620 - val_loss: 0.6645 - val_accuracy: 0.9160
# Epoch 101/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9651
# Epoch 101: val_loss did not improve from 0.58989
# 704/704 [==============================] - 122s 173ms/step - loss: 0.1037 - accuracy: 0.9651 - val_loss: 0.7223 - val_accuracy: 0.9071
# Epoch 102/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9671
# Epoch 102: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.0961 - accuracy: 0.9671 - val_loss: 0.8421 - val_accuracy: 0.8968
# Epoch 103/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9654
# Epoch 103: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1010 - accuracy: 0.9654 - val_loss: 0.7191 - val_accuracy: 0.9097
# Epoch 104/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9631
# Epoch 104: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1089 - accuracy: 0.9631 - val_loss: 0.7112 - val_accuracy: 0.9037
# Epoch 105/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9643
# Epoch 105: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 174ms/step - loss: 0.1050 - accuracy: 0.9643 - val_loss: 0.7189 - val_accuracy: 0.9077
# Epoch 106/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9675
# Epoch 106: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.0940 - accuracy: 0.9675 - val_loss: 0.6528 - val_accuracy: 0.9193
# Epoch 107/150
# 703/704 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9630
# Epoch 107: val_loss did not improve from 0.58989
# 704/704 [==============================] - 123s 175ms/step - loss: 0.1093 - accuracy: 0.9630 - val_loss: 0.7047 - val_accuracy: 0.9112
# Epoch 107: early stopping

# %%
# load the saved best model weights
act_model.load_weights('all_rotated_1.hdf5')
 
# predict outputs on validation images
prediction = act_model.predict(valid_img[10:20])
 
# use CTC decoder
out = K.get_value(K.ctc_decode(prediction, input_length=np.ones(prediction.shape[0])*prediction.shape[1],
                         greedy=True)[0][0])
 
# see the results
i = 10
for x in out:
    print("original_text = ", valid_orig_txt[i])
    print("predicted text = ", end = '')
    for p in x:  
        if int(p) != -1:
            print(char_list[int(p)], end = '')       
    print('\n')
    i+=1
# Out:
# original_text =  &S2i6'KbJ!D&/
# predicted text = &S2i6'KbJ!D&/
#
# original_text =  g^
# predicted text = g^
#
# original_text =  t;QHGghH#mhEP$:v
# predicted text = t;QHGghH#mhEP$:v
#
# original_text =  ibnFN&IFb2|
# predicted text = ibnFN&IFb2|
#
# original_text =  5wg0+Su
# predicted text = 5wg0+Su
#
# original_text =  y
# predicted text = y
#
# original_text =  -bqE(x%3;^V;aK
# predicted text = -bqE(x%3;^V;aK
#
# original_text =  B6+f7o9|Di]
# predicted text = B6+f7o9|Di]
#
# original_text =  JemPNtt1r9oRf&hp:oi&
# predicted text = JemPNtt1r9oRf&hp:oi&
#
# original_text =  ]W99g@720UK1g6XvCL'
# predicted text = ]W99g@720UK1g6XvCU'

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.savefig('all_rotated1.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
